# %% [markdown]
# # Step 2: Model Building & Evaluation

# %%
# import the libraries
from tensorflow import keras
#print(keras.__version__)

import h5py
import os
import pandas as pd
import numpy as np

import urllib
import glob
import pickle
import re

from sklearn.metrics import confusion_matrix, recall_score, precision_score
from keras.models import Sequential
from sklearn import datasets
from imblearn.under_sampling import RandomUnderSampler
from keras.layers import Dense, Dropout, LSTM, Activation

print('Import complete successfully!')
# Out:
# Import complete successfully!

# %% [markdown]
# ## Load feature data set

# %%
train_df = pd.read_csv('./data/preparedData/PM_train_prepared.csv', sep=",", header=0)
train_df.head(10)
# Out:
#               datetime  machineID  cycle     model  age      volt    rotate  \
# 0  2015-01-01 06:00:00          1      1  0.666667  0.9  0.499928  0.503194
# 1  2015-01-01 07:00:00          1      2  0.666667  0.9  0.415395  0.474884
# 2  2015-01-01 08:00:00          1      3  0.666667  0.9  0.466796  0.698752
# 3  2015-01-01 09:00:00          1      4  0.666667  0.9  0.412756  0.373197
# 4  2015-01-01 10:00:00          1      5  0.666667  0.9  0.382001  0.533508
# 5  2015-01-01 11:00:00          1      6  0.666667  0.9  0.476397  0.524429
# 6  2015-01-01 12:00:00          1      7  0.666667  0.9  0.375322  0.647946
# 7  2015-01-01 13:00:00          1      8  0.666667  0.9  0.476511  0.487240
# 8  2015-01-01 14:00:00          1      9  0.666667  0.9  0.494267  0.467520
# 9  2015-01-01 15:00:00          1     10  0.666667  0.9  0.455570  0.579276
#
#    pressure  vibration  RUL  label1  label2  cycle_norm
# 0  0.459050   0.487945   96       0       0    0.000000
# 1  0.328274   0.460912   95       0       0    0.000154
# 2  0.178160   0.311752   94       0       0    0.000309
# 3  0.430624   0.423896   93       0       0    0.000463
# 4  0.450207   0.179498   92       0       0    0.000617
# 5  0.331737   0.335594   91       0       0    0.000772
# 6  0.449235   0.450251   90       0       0    0.000926
# 7  0.369402   0.332800   89       0       0    0.001080
# 8  0.440837   0.494318   88       0       0    0.001235
# 9  0.397960   0.404184   87       0       0    0.001389

# %%
#balancing training data
#print('Balancing train data is in progress...')
df_train = train_df[["datetime","machineID","cycle","model","age","volt","rotate","pressure","vibration","RUL","label2","cycle_norm"]]
y_train = train_df["label1"]
rus = RandomUnderSampler()
#rus = RandomUnderSampler(sampling_strategy={0:30000})
df_resampled, y_resampled = rus.fit_resample(df_train, y_train)
df_balanced = pd.concat([df_resampled, y_resampled],axis=1)
train_df = df_balanced.sort_values(['machineID', 'datetime'], ascending=[True, True])
train_df = train_df[['datetime','machineID', 'cycle', 'model', 'age', 'volt', 'rotate', 'pressure', 'vibration', 'RUL', 'cycle_norm', 'label1', 'label2']]
train_df.drop(train_df.columns[[0]], axis=1, inplace=True)
train_df.head(10)
#print('Balancing train data completed successfully.')
# Out:
#        machineID  cycle     model  age      volt    rotate  pressure  \
# 18336          1     25  0.666667  0.9  0.633936  0.554290  0.468433
# 2969           1     51  0.666667  0.9  0.424662  0.773534  0.321059
# 19935          1     67  0.666667  0.9  0.620057  0.534940  0.390426
# 19936          1     68  0.666667  0.9  0.453993  0.590838  0.489264
# 19937          1     69  0.666667  0.9  0.430023  0.604926  0.470232
# 19938          1     70  0.666667  0.9  0.600360  0.661463  0.463462
# 19939          1     71  0.666667  0.9  0.622540  0.441451  0.410613
# 19940          1     72  0.666667  0.9  0.464634  0.585275  0.389755
# 19941          1     73  0.666667  0.9  0.428900  0.557030  0.344969
# 19942          1     74  0.666667  0.9  0.287297  0.529740  0.501922
#
#        vibration  RUL  cycle_norm  label1  label2
# 18336   0.236628   72    0.003704       0       0
# 2969    0.551515   46    0.007717       0       0
# 19935   0.566431   30    0.010187       1       1
# 19936   0.702829   29    0.010341       1       1
# 19937   0.689213   28    0.010495       1       1
# 19938   0.693415   27    0.010650       1       1
# 19939   0.561752   26    0.010804       1       1
# 19940   0.703889   25    0.010958       1       1
# 19941   0.538842   24    0.011113       1       1
# 19942   0.645600   23    0.011267       1       1

# %%
test_df = pd.read_csv('./data/preparedData/PM_test_prepared.csv', sep=",", header=0)
test_df.head(10)
# Out:
#    machineID  cycle     model       age      volt    rotate  pressure  \
# 0         89      1  0.666667  0.833333  0.420252  0.816190  0.653248
# 1         89      2  0.666667  0.833333  0.408611  0.762715  0.829219
# 2         89      3  0.666667  0.833333  0.250609  0.301397  0.657232
# 3         89      4  0.666667  0.833333  0.497216  0.554726  0.809499
# 4         89      5  0.666667  0.833333  0.418949  0.471659  0.482283
# 5         89      6  0.666667  0.833333  0.523158  0.518877  0.767339
# 6         89      7  0.666667  0.833333  0.457698  0.741963  0.429188
# 7         89      8  0.666667  0.833333  0.437202  0.455160  0.392089
# 8         89      9  0.666667  0.833333  0.477320  0.468083  0.469835
# 9         89     10  0.666667  0.833333  0.492070  0.599858  0.345500
#
#    vibration  RUL  cycle_norm  label1  label2
# 0   0.549285  888    0.000000       0       0
# 1   0.476602  887    0.000198       0       0
# 2   0.357829  886    0.000397       0       0
# 3   0.160269  885    0.000595       0       0
# 4   0.490419  884    0.000794       0       0
# 5   0.514914  883    0.000992       0       0
# 6   0.376204  882    0.001191       0       0
# 7   0.416383  881    0.001389       0       0
# 8   0.461749  880    0.001588       0       0
# 9   0.507347  879    0.001786       0       0

# %% [markdown]
# ## Modelling

# %%
# pick a large window size of 120 cycles
sequence_length = 120

# %%
# function to reshape features into (samples, time steps, features) 
def gen_sequence(id_df, seq_length, seq_cols):
    """ Only sequences that meet the window-length are considered, no padding is used. This means for testing
    we need to drop those which are below the window-length. An alternative would be to pad sequences so that
    we can use shorter ones """
    data_array = id_df[seq_cols].values
    num_elements = data_array.shape[0]
    for start, stop in zip(range(0, num_elements-seq_length), range(seq_length, num_elements)):
        yield data_array[start:stop, :]

# %%
# pick the feature columns 
sequence_cols = ['cycle_norm']
key_cols = ['machineID', 'cycle']
label_cols = ['label1', 'label2', 'RUL']

input_features = test_df.columns.values.tolist()
sensor_cols = [x for x in input_features if x not in set(key_cols)]
sensor_cols = [x for x in sensor_cols if x not in set(label_cols)]
sensor_cols = [x for x in sensor_cols if x not in set(sequence_cols)]

# The time is sequenced along
# This may be a silly way to get these column names, but it's relatively clear
sequence_cols.extend(sensor_cols)

print(sensor_cols)
print(sequence_cols)
# Out:
# ['model', 'age', 'volt', 'rotate', 'pressure', 'vibration']
# ['cycle_norm', 'model', 'age', 'volt', 'rotate', 'pressure', 'vibration']

# %%
# generator for the sequences
seq_gen = (list(gen_sequence(train_df[train_df['machineID']==id], sequence_length, sequence_cols)) 
           for id in train_df['machineID'].unique())

seq_array = np.concatenate(list(seq_gen)).astype(np.float32)
seq_array.shape
# Out:
# (29070, 120, 7)

# %%
# function to generate labels
def gen_labels(id_df, seq_length, label):
    data_array = id_df[label].values
    num_elements = data_array.shape[0]
    return data_array[seq_length:num_elements, :]

# %%
# generate labels
label_gen = [gen_labels(train_df[train_df['machineID']==id], sequence_length, ['label1']) 
             for id in train_df['machineID'].unique()]
label_array = np.concatenate(label_gen).astype(np.float32)
label_array.shape
# Out:
# (29070, 1)

# %% [markdown]
# ## LSTM Network

# %%
# build the network
# Feature weights
nb_features = seq_array.shape[2]
nb_out = label_array.shape[1]

# LSTM model
model = Sequential()

# The first layer
model.add(LSTM(
         input_shape=(sequence_length, nb_features),
         units=400,
         return_sequences=True))

# Plus a 20% dropout rate
model.add(Dropout(0.2))

# The second layer
model.add(LSTM(
          units=200,
          return_sequences=False))

# Plus a 20% dropout rate
model.add(Dropout(0.2))

# Dense sigmoid layer
model.add(Dense(units=nb_out, activation='sigmoid'))

#lr_schedule = 1e-4
#lr_schedule = keras.optimizers.schedules.ExponentialDecay(
#    initial_learning_rate=1e-3,
#    decay_steps=1000,
#    decay_rate=0.9)

# With adam optimizer and a binary crossentropy loss. We will opimize for model accuracy.
#model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['binary_accuracy'])

model.compile(loss="binary_crossentropy",
    optimizer=keras.optimizers.Adam(),          
    #optimizer=keras.optimizers.Adam(learning_rate=lr_schedule),
    metrics=["binary_accuracy"])

# Verify the architecture 
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 120, 400)          652800
#
#  dropout (Dropout)           (None, 120, 400)          0
#
#  lstm_1 (LSTM)               (None, 200)               480800
#
#  dropout_1 (Dropout)         (None, 200)               0
#
#  dense (Dense)               (None, 1)                 201
#
# =================================================================
# Total params: 1,133,801
# Trainable params: 1,133,801
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# %%time
# fit the network
model.fit(seq_array, # Training features
          label_array, # Training labels
          epochs=30,   # We'll stop after 10 epochs
          batch_size=16, # 
          validation_split=0.3, # Use 30% of data to evaluate the loss. (val_loss)
          verbose=1, #
          callbacks = [keras.callbacks.EarlyStopping(monitor='val_binary_accuracy', # Monitor the validation binary accuracy
                                                     min_delta=0,    # until it doesn't change (or gets worse)
                                                     patience=7,  # patience > 1 so it continutes if it is not consistently improving
                                                     verbose=0, 
                                                     mode='auto',
                                                     restore_best_weights=True)])
# Out:
# Epoch 1/30
# 1272/1272 [==============================] - 2166s 2s/step - loss: 0.5238 - binary_accuracy: 0.7388 - val_loss: 0.4611 - val_binary_accuracy: 0.7808
# Epoch 2/30
# 1272/1272 [==============================] - 2180s 2s/step - loss: 0.4129 - binary_accuracy: 0.8136 - val_loss: 0.4069 - val_binary_accuracy: 0.8150
# Epoch 3/30
# 1272/1272 [==============================] - 2217s 2s/step - loss: 0.3735 - binary_accuracy: 0.8361 - val_loss: 0.4860 - val_binary_accuracy: 0.7704
# Epoch 4/30
# 1272/1272 [==============================] - 2204s 2s/step - loss: 0.3377 - binary_accuracy: 0.8555 - val_loss: 0.3521 - val_binary_accuracy: 0.8505
# Epoch 5/30
# 1272/1272 [==============================] - 2222s 2s/step - loss: 0.3026 - binary_accuracy: 0.8740 - val_loss: 0.3388 - val_binary_accuracy: 0.8532
# Epoch 6/30
# 1272/1272 [==============================] - 2193s 2s/step - loss: 0.2775 - binary_accuracy: 0.8885 - val_loss: 0.3064 - val_binary_accuracy: 0.8797
# Epoch 7/30
# 1272/1272 [==============================] - 2201s 2s/step - loss: 0.2894 - binary_accuracy: 0.8847 - val_loss: 0.2814 - val_binary_accuracy: 0.8849
# Epoch 8/30
# 1272/1272 [==============================] - 2217s 2s/step - loss: 0.2469 - binary_accuracy: 0.9032 - val_loss: 0.3392 - val_binary_accuracy: 0.8713
# Epoch 9/30
# 1272/1272 [==============================] - 2215s 2s/step - loss: 0.2387 - binary_accuracy: 0.9057 - val_loss: 0.2864 - val_binary_accuracy: 0.8875
# Epoch 10/30
# 1272/1272 [==============================] - 2223s 2s/step - loss: 0.2314 - binary_accuracy: 0.9094 - val_loss: 0.2904 - val_binary_accuracy: 0.8861
# Epoch 11/30
# 1272/1272 [==============================] - 2223s 2s/step - loss: 0.2187 - binary_accuracy: 0.9145 - val_loss: 0.6553 - val_binary_accuracy: 0.7769
# Epoch 12/30
# 1272/1272 [==============================] - 2218s 2s/step - loss: 0.2585 - binary_accuracy: 0.9012 - val_loss: 0.2729 - val_binary_accuracy: 0.8977
# Epoch 13/30
# 1272/1272 [==============================] - 2237s 2s/step - loss: 0.3511 - binary_accuracy: 0.8265 - val_loss: 0.7243 - val_binary_accuracy: 0.4884
# Epoch 14/30
# 1272/1272 [==============================] - 2245s 2s/step - loss: 0.7527 - binary_accuracy: 0.5054 - val_loss: 0.6910 - val_binary_accuracy: 0.5176
# Epoch 15/30
# 1272/1272 [==============================] - 2252s 2s/step - loss: 0.7100 - binary_accuracy: 0.5069 - val_loss: 0.6925 - val_binary_accuracy: 0.4882
# Epoch 16/30
# 1272/1272 [==============================] - 2261s 2s/step - loss: 0.6545 - binary_accuracy: 0.6077 - val_loss: 0.4266 - val_binary_accuracy: 0.8095
# Epoch 17/30
# 1272/1272 [==============================] - 2265s 2s/step - loss: 0.3235 - binary_accuracy: 0.8694 - val_loss: 0.2724 - val_binary_accuracy: 0.8945
# Epoch 18/30
# 1272/1272 [==============================] - 2269s 2s/step - loss: 0.2642 - binary_accuracy: 0.8974 - val_loss: 0.3138 - val_binary_accuracy: 0.8689
# Epoch 19/30
# 1272/1272 [==============================] - 2272s 2s/step - loss: 0.2359 - binary_accuracy: 0.9099 - val_loss: 0.2489 - val_binary_accuracy: 0.9055
# Epoch 20/30
# 1272/1272 [==============================] - 2275s 2s/step - loss: 0.2216 - binary_accuracy: 0.9150 - val_loss: 0.2488 - val_binary_accuracy: 0.9093
# Epoch 21/30
# 1272/1272 [==============================] - 2285s 2s/step - loss: 0.2358 - binary_accuracy: 0.9076 - val_loss: 0.2371 - val_binary_accuracy: 0.9062
# Epoch 22/30
# 1272/1272 [==============================] - 2315s 2s/step - loss: 0.2231 - binary_accuracy: 0.9140 - val_loss: 0.2454 - val_binary_accuracy: 0.9059
# Epoch 23/30
# 1272/1272 [==============================] - 2289s 2s/step - loss: 0.2102 - binary_accuracy: 0.9202 - val_loss: 0.2566 - val_binary_accuracy: 0.9054
# Epoch 24/30
# 1272/1272 [==============================] - 2316s 2s/step - loss: 0.2008 - binary_accuracy: 0.9237 - val_loss: 0.2460 - val_binary_accuracy: 0.9098
# Epoch 25/30
# 1272/1272 [==============================] - 2327s 2s/step - loss: 0.2125 - binary_accuracy: 0.9184 - val_loss: 0.4157 - val_binary_accuracy: 0.8196
# Epoch 26/30
# 1272/1272 [==============================] - 2383s 2s/step - loss: 0.2070 - binary_accuracy: 0.9218 - val_loss: 0.2437 - val_binary_accuracy: 0.9098
# Epoch 27/30
# 1272/1272 [==============================] - 2409s 2s/step - loss: 0.2080 - binary_accuracy: 0.9197 - val_loss: 0.2258 - val_binary_accuracy: 0.9129
# Epoch 28/30
# 1272/1272 [==============================] - 2379s 2s/step - loss: 0.1859 - binary_accuracy: 0.9286 - val_loss: 0.2580 - val_binary_accuracy: 0.8997
# Epoch 29/30
# 1272/1272 [==============================] - 2392s 2s/step - loss: 0.1811 - binary_accuracy: 0.9308 - val_loss: 0.2414 - val_binary_accuracy: 0.9051
# Epoch 30/30
# 1272/1272 [==============================] - 2370s 2s/step - loss: 0.1853 - binary_accuracy: 0.9295 - val_loss: 0.2401 - val_binary_accuracy: 0.9099
# CPU times: total: 4d 4h 16min 28s
# Wall time: 18h 53min 40s

# %%
# training metrics
scores = model.evaluate(seq_array, label_array, verbose=1, batch_size=200)
print('Training Accurracy: {}'.format(scores[1]))
# Out:
# 146/146 [==============================] - 590s 4s/step - loss: 0.1913 - binary_accuracy: 0.9258
# Training Accurracy: 0.9258341789245605

# %%
# make predictions and compute confusion matrix
y_pred = (model.predict(seq_array,verbose=1, batch_size=200) > 0.5).astype("int32")
y_true = label_array
print('Training Confusion matrix\n- x-axis is true labels.\n- y-axis is predicted labels')
cm = confusion_matrix(y_true, y_pred)
cm
# Out:
# 146/146 [==============================] - 586s 4s/step
# Training Confusion matrix
# - x-axis is true labels.
# - y-axis is predicted labels
# array([[13644,   584],
#        [ 1572, 13270]], dtype=int64)

# %%
# compute precision and recall
precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred)
f1 = 2 * (precision * recall) / (precision + recall)
print( 'Training Precision: ', precision, '\n', 'Training Recall: ', recall, '\n', 'Training F1 Score:', f1)
# Out:
# Training Precision:  0.9578461094268803
#  Training Recall:  0.894084355208193
#  Training F1 Score: 0.9248675773626985

# %% [markdown]
# ## Model testing

# %%
seq_array_test_last = [test_df[test_df['machineID']==id][sequence_cols].values[-sequence_length:] 
                       for id in test_df['machineID'].unique() if len(test_df[test_df['machineID']==id]) >= sequence_length]

seq_array_test_last = np.asarray(seq_array_test_last).astype(np.float32)
seq_array_test_last.shape
# Out:
# (8, 120, 7)

# %%
y_mask = [len(test_df[test_df['machineID']==id]) >= sequence_length for id in test_df['machineID'].unique()]

label_array_test_last = test_df.groupby('machineID')['label1'].nth(-1)[y_mask].values
label_array_test_last = label_array_test_last.reshape(label_array_test_last.shape[0],1).astype(np.float32)
label_array_test_last.shape

print(seq_array_test_last.shape)
print(label_array_test_last.shape)
# Out:
# (8, 120, 7)
# (8, 1)

# %%
# test metrics
scores_test = model.evaluate(seq_array_test_last, label_array_test_last, verbose=2)
print('Test Accurracy: {}'.format(scores_test[1]))
# Out:
# 1/1 - 0s - loss: 0.5163 - binary_accuracy: 0.7500 - 333ms/epoch - 333ms/step
# Test Accurracy: 0.75

# %% [markdown]
# Similarly for the test set confusion matrix.

# %%
# make predictions and compute confusion matrix
y_pred_test = (model.predict(seq_array_test_last,verbose=1, batch_size=200) > 0.5).astype("int32")
y_true_test = label_array_test_last
print('Confusion matrix\n- x-axis is true labels.\n- y-axis is predicted labels')
cm = confusion_matrix(y_true_test, y_pred_test)
cm
# Out:
# 1/1 [==============================] - 0s 458ms/step
# Confusion matrix
# - x-axis is true labels.
# - y-axis is predicted labels
# array([[0, 1],
#        [1, 6]], dtype=int64)

# %%
# compute precision and recall
precision_test = precision_score(y_true_test, y_pred_test)
recall_test = recall_score(y_true_test, y_pred_test)
f1_test = 2 * (precision_test * recall_test) / (precision_test + recall_test)
print( 'Test Precision: ', precision_test, '\n', 'Test Recall: ', recall_test, '\n', 'Test F1 Score:', f1_test)
# Out:
# Test Precision:  0.8571428571428571
#  Test Recall:  0.8571428571428571
#  Test F1 Score: 0.8571428571428571

# %% [markdown]
# ## Saving or loading the model

# %%
import os
import h5py
from sklearn import datasets 
 
model.save('models/machineRULPredictor.h5')
print("Model saved")
# Out:
# Model saved

# %%
model = keras.models.load_model('models/machineRULPredictor.h5')
print("Model loaded")
